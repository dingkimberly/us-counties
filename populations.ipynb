# %%
import csv
from common import tsv_to_dict

# county population data: https://www.census.gov/data/datasets/time-series/demo/popest/2010s-counties-total.html

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
name_to_fips = tsv_to_dict('fips_to_name.tsv', 1, 0)
# Out:
# {'Autauga County, AL': '01001', 'Chilton County, AL': '01021', 'Dallas County, AL': '01047', 'Elmore County, AL': '01051', 'Lowndes County, AL': '01085', 'Montgomery County, AL': '01101', 'Baldwin County, AL': '01003', 'Clarke County, AL': '01025', 'Escambia County, AL': '01053', 'Mobile County, AL': '01097', 'Monroe County, AL': '01099', 'Washington County, AL': '01129', 'Escambia County, FL': '12033', 'Barbour County, AL': '01005', 'Bullock County, AL': '01011', 'Dale County, AL': '01045', 'Henry County, AL': '01067', 'Pike County, AL': '01109', 'Russell County, AL': '01113', 'Clay County, GA': '13061', 'Quitman County, GA': '13239', 'Stewart County, GA': '13259', 'Bibb County, AL': '01007', 'Hale County, AL': '01065', 'Jefferson County, AL': '01073', 'Perry County, AL': '01105', 'Shelby County, AL': '01117', 'Tuscaloosa County, AL': '01125', 'Blount County, AL': '01009', 'Cullman County, AL': '01043', 'Etowah County, AL': '01055', 'Marshall County, AL': '01095', 'St Clair County, AL': '01115', 'Walker County, AL': '01127', 'Macon County, AL': '01087', 'Butler County, AL': '01013', 'Conecuh County, AL': '01035', 'Covington County, AL': '01039', 'Crenshaw County, AL': '01041', 'Wilcox County, AL': '01131', 'Calhoun County, AL': '01015', 'Cherokee County, AL': '01019', 'Cleburne County, AL': '01029', 'Talladega County, AL': '01121', 'Chambers County, AL': '01017', 'Lee County, AL': '01081', 'Randolph County, AL': '01111', 'Tallapoosa County, AL': '01123', 'Harris County, GA': '13145', 'Troup County, GA': '13285', 'DeKalb County, AL': '01049', 'Chattooga County, GA': '13055', 'Floyd County, GA': '13115', 'Polk County, GA': '13233', 'Coosa County, AL': '01037', 'Choctaw County, AL': '01023', 'Marengo County, AL': '01091', 'Sumter County, AL': '01119', 'Clarke County, MS': '28023', 'Lauderdale County, MS': '28075', 'Wayne County, MS': '28153', 'Clay County, AL': '01027', 'Carroll County, GA': '13045', 'Haralson County, GA': '13143', 'Coffee County, AL': '01031', 'Geneva County, AL': '01061', 'Colbert County, AL': '01033', 'Franklin County, AL': '01059', 'Lauderdale County, AL': '01077', 'Lawrence County, AL': '01079', 'Tishomingo County, MS': '28141', 'Okaloosa County, FL': '12091', 'Walton County, FL': '12131', 'Morgan County, AL': '01103', 'Winston County, AL': '01133', 'Houston County, AL': '01069', 'Jackson County, AL': '01071', 'Dade County, GA': '13083', 'Walker County, GA': '13295', 'Santa Rosa County, FL': '12113', 'Fayette County, AL': '01057', 'Lamar County, AL': '01075', 'Marion County, AL': '01093', 'Pickens County, AL': '01107', 'Itawamba County, MS': '28057', 'Holmes County, FL': '12059', 'Jackson County, FL': '12063', 'Greene County, AL': '01063', 'Early County, GA': '13099', 'Seminole County, GA': '13253', 'Madison County, AL': '01089', 'Franklin County, TN': '47051', 'Marion County, TN': '47115', 'Lowndes County, MS': '28087', 'Monroe County, MS': '28095', 'Limestone County, AL': '01083', 'Giles County, TN': '47055', 'Hardin County, TN': '47071', 'Lawrence County, TN': '47099', 'Wayne County, TN': '47181', 'Muscogee County, GA': '13215', 'Lincoln County, TN': '47103', 'George County, MS': '28039', 'Greene County, MS': '28041', 'Jackson County, MS': '28059', 'Noxubee County, MS': '28103', 'Heard County, GA': '13149', 'Chattahoochee County, GA': '13053', 'Kemper County, MS': '28069', 'Aleutians East Borough, AK': '02013', 'Aleutians West Census Area, AK': '02016', 'Lake and Peninsula Borough, AK': '02164', 'Anchorage Municipality, AK': '02020', 'Kenai Peninsula Borough, AK': '02122', 'Matanuska-Susitna Borough, AK': '02170', 'Valdez-Cordova Census Area, AK': '02261', 'Bethel Census Area, AK': '02050', 'Dillingham Census Area, AK': '02070', 'Wade Hampton Census Area, AK': '02270', 'Yukon-Koyukuk Census Area, AK': '02290', 'Bristol Bay Borough, AK': '02060', 'Denali Borough, AK': '02068', 'Fairbanks North Star Borough, AK': '02090', 'Southeast Fairbanks Census Area, AK': '02240', 'Haines Borough, AK': '02100', 'Hoona ...

# %%
with open('co-est2019-annres.csv', 'r', encoding='latin-1') as fp:
    with open('fips_to_population.tsv', 'w') as tsvfile:
        
        writer = csv.writer(tsvfile, delimiter='\t')
        reader = csv.reader(fp)

        for row in reader:
            if row[0] == 'Area':
                continue

            if len(row) > 1: 
                names = row[0].replace('.','').split(',')
                pop = int(row[12].replace(',',''))
                name = names[0].strip() + ", " + us_state_abbrev[names[1].strip()]
                
                try:
                    fips = name_to_fips[name]
                    writer.writerow([fips, pop])
                except KeyError:
                    print(name)
# Out:
# Petersburg Borough, AK
# LaSalle Parish, LA
# Do̱a Ana County, NM
# Oglala Lakota County, SD
