# %%
import csv

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
with open('co-est2019-annres.csv', 'r', encoding='latin-1') as fp:
    
    reader = csv.reader(fp)
    
    for row in reader:
        if row[0] == 'Area':
            continue

        if len(row) > 1: 
            name = row[0].replace('.','').split(',')
            pop = int(row[12].replace(',',''))
            county = name[0].strip() + ", " + us_state_abbrev[name[1].strip()]
            print(county)
            print(pop)
# Out:
# Autauga County, AL
# 55869
# Baldwin County, AL
# 223234
# Barbour County, AL
# 24686
# Bibb County, AL
# 22394
# Blount County, AL
# 57826
# Bullock County, AL
# 10101
# Butler County, AL
# 19448
# Calhoun County, AL
# 113605
# Chambers County, AL
# 33254
# Cherokee County, AL
# 26196
# Chilton County, AL
# 44428
# Choctaw County, AL
# 12589
# Clarke County, AL
# 23622
# Clay County, AL
# 13235
# Cleburne County, AL
# 14910
# Coffee County, AL
# 52342
# Colbert County, AL
# 55241
# Conecuh County, AL
# 12067
# Coosa County, AL
# 10663
# Covington County, AL
# 37049
# Crenshaw County, AL
# 13772
# Cullman County, AL
# 83768
# Dale County, AL
# 49172
# Dallas County, AL
# 37196
# DeKalb County, AL
# 71513
# Elmore County, AL
# 81209
# Escambia County, AL
# 36633
# Etowah County, AL
# 102268
# Fayette County, AL
# 16302
# Franklin County, AL
# 31362
# Geneva County, AL
# 26271
# Greene County, AL
# 8111
# Hale County, AL
# 14651
# Henry County, AL
# 17205
# Houston County, AL
# 105882
# ...
